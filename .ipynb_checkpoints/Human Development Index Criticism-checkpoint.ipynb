# %% [markdown]
#    # CAPSTONE PROJECT

# %% [markdown]
# #### PROBLEM Statement :
# - Critic overview on the Human Development Index on Environmental Safety and Economic health
#
# Theory:
# The United Nations Development Program have set an index called the Human Development Index ‘HDI’ to masseur the development and life quality in each country on detailed attributes within three main aspects of human life: Health, Education and Income.
# The importance within this index relies on the fact that it sets the role models countries for other countries to follow it polices and guidelines in order to active the same level of development as well, so the index should be reliable and well generlized.
#
# My theory states that NOT every country that increases in it HDI will contribute positively with Environmental, personal safety and Economic health in which will make the HDI is questionable and not sufficient to make a fair or reliable judgment for the development within these countries.
# Espicaly the Arabic countries in the environmental part.
#
# **Approach:**
#
# - **First critic overview, Environmental**
# - I will take the countries with HDI increase rate between 2012 and 2017,compare it to the PM2.5 air pollution exposure.
# - Exposure to PM2.5 has multiple short term and long term health impacts, A prolonged exposure to PM2.5 can cause permanent respiratory problems such as asthma, chronic bronchitis and heart disease.
# Research shows that every 10ug/m3 increase in PM 2.5, increases all-cause mortality between 3-26%, chances of childhood asthma by 16%, chances of lung cancer by 36% and heart attacks by 44%.
#
# - **Second critic overview, Personal Safety index**
# - The countries that passed the first critic overview will be taken to see the rates of the personal safety percentage change within the five years.
# -The personal safety index is a percentage that Mauser the scores of Homicide rate, Perceived criminality, Political killings and torture, Traffic deaths.
# This index is developed by The Social Progress Imperative - Washington, DC.
#
# - **Third critic overview,, -Economic health:**
#
# - The countries that passed the first and second critic overview will be uptaken to see state of it debt-to-GDP percentage.
#
# - The debt-to-GDP percentage is the metric comparing a country's public debt to its gross domestic product (GDP). By comparing what a country owes with what it produces, the debt-to-GDP ratio reliably indicates that particular country’s ability to pay back its debts.
#
# - i will see which countries that manged to reduce the dept and then i will fetch the healthier economic one by taking the countries with less than 77% debt-to-GDP, as a study by the World Bank found that if the debt-to-GDP ratio of a country exceeds 77% for an extended period of time, it slows economic growth and puts the countries in higher economic risks.
#
# - **Intervention:**
# - intervention will be discussed with the conclusion

# %% [markdown]
# # Importting libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
sns.set_style('white')
co=['#174147','#98B6C1','#2C8592','#BFD1D7','#05BCD8','#96E4F0','#216772','#B2E0F0']
import patsy
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
sns.set(font_scale=1.5)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
cols= ['#B2E0F0','#174147','#BFD1D7']
cols_= ['#B2E0F0','#174147','#BFD1D7','#2C8592']

# %% [markdown]
# # Part one - HDI

# %% [markdown]
# ## Importing the human developmnt index -HDI-

# %%
hdi= pd.read_csv('HDI_.csv').round(2)

# %%
hdi = hdi.set_index(['Country_'])

# %% [markdown]
# ### Find the countries that incresed in the HDI rate in the on 2012-2017

# %%
hdi['change_rate'] =  (hdi.HDI_2017-hdi.HDI_2012)/hdi.HDI_2012*100

# %% [markdown]
# ### Take the countries with incresed HDI

# %%
subset_high_C = hdi[(hdi['change_rate'] >= 0)] #subset

# %%
subset_high_C.shape #check shape
# Out:
# (156, 10)

# %%
subset_high_C.round(2).head() #check the datafram
# Out:
#              HDI_2010  HDI_2011  HDI_2012  HDI_2013  HDI_2014  HDI_2015  \
# Country_
# Afghanistan      0.46      0.47      0.48      0.49      0.49      0.49
# Albania          0.74      0.75      0.77      0.77      0.77      0.78
# Algeria          0.73      0.74      0.74      0.74      0.75      0.75
# Argentina        0.81      0.82      0.82      0.82      0.82      0.82
# Armenia          0.73      0.73      0.74      0.74      0.74      0.75
#
#              HDI_2016  HDI_2017      Country  change_rate
# Country_
# Afghanistan      0.49      0.50  Afghanistan         4.17
# Albania          0.78      0.78      Albania         1.30
# Algeria          0.75      0.75      Algeria         1.35
# Argentina        0.82      0.82    Argentina         0.00
# Armenia          0.75      0.76      Armenia         2.70

# %% [markdown]
# #### Out of 160 countries, 156 countries incresed in thier HDI ,
#
# Now i will just check the countries with decresed HDI

# %%
subset_low_c = hdi[(hdi['change_rate'] < 0)]

# %%
subset_low_c
# Out:
#            HDI_2010  HDI_2011  HDI_2012  HDI_2013  HDI_2014  HDI_2015  \
# Country_
# Libya          0.76      0.71      0.74      0.71      0.70      0.69
# Syria          0.64      0.64      0.63      0.57      0.55      0.54
# Venezuela      0.76      0.77      0.77      0.78      0.78      0.78
# Yemen          0.50      0.50      0.50      0.51      0.50      0.48
#
#            HDI_2016  HDI_2017    Country  change_rate
# Country_
# Libya          0.69      0.71      Libya    -4.054054
# Syria          0.54      0.54      Syria   -14.285714
# Venezuela      0.77      0.76  Venezuela    -1.298701
# Yemen          0.46      0.45      Yemen   -10.000000

# %% [markdown]
# it is logical for these countries to have lower HDI regarding thier war and political distress.

# %% [markdown]
# # Visualzation for part one

# %% [markdown]
# #### lets plot the chnage within between 2012-2017 years in general

# %%
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=hdi['Country'],
                y=hdi['HDI_2012'],
                name="HDI in 2012",
                line_color='blue',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=hdi['Country'],
                y=hdi['HDI_2017'],
                name="HDI in 2017",
                line_color='green',
                opacity=0.8))
# Use date string to set xaxis range
title_text="Changes Between 2012-2017"
fig.show()
# Out:
# <div>
#
#
#             <div id="f35025eb-dfb6-40eb-8a1d-8bb2f87f294d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f35025eb-dfb6-40eb-8a1d-8bb2f87f294d")) {
#                     Plotly.newPlot(
#                         'f35025eb-dfb6-40eb-8a1d-8bb2f87f294d',
#                         [{"line": {"color": "blue"}, "name": "HDI in 2012", "opacity": 0.8, "type": "scatter", "x": ["Afghanistan", "Albania", "Algeria", "Argentina", "Armenia", "Australia", "Austria", "Azerbaijan", "Bahamas", "Bahrain", "Bangladesh", "Belarus", "Belgium", "Benin", "Bhutan", "Bolivia ", "Bosnia_and_Herzegovina", "Botswana", "Brazil", "Brunei_Darussalam", "Bulgaria", "Burkina_Faso", "Burundi", "Cabo_Verde", "Cambodia", "Cameroon", "Canada", "Central_African", "Chad", "Chile", "China", "Colombia", "Congo", "Costa_Rica", "C\u00f4te_d_Ivoire", "Croatia", "Cuba", "Cyprus", "Czechia", "Denmark", "Djibouti", "Dominican_Republic", "Ecuador", "Egypt", "Equatorial_Guinea", "Eritrea", "Estonia", "Eswatini ", "Ethiopia", "Fiji", "Finland", "France", "Gabon", "Gambia", "Georgia", "Germany", "Ghana", "Greece", "Guinea", "Guinea_Bissau", "Hong Kong", "Hungary", "Iceland", "India", "Indonesia", "Iran", "Iraq", "Ireland", "Italy", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Korea", "Kuwait", "Kyrgyzstan", "Latvia", "Lebanon", "Liberia", "Libya", "Liechtenstein", "Lithuania", "Luxembourg", "Macedonia", "Madagascar", "Malawi", "Malaysia", "Maldives", "Mali", "Malta", "Mauritania", "Mauritius", "Mexico", "Micronesia", "Montenegro", "Morocco", "Mozambique", "Myanmar", "Nepal", "Netherlands", "New Zealand", "Nicaragua", "Niger", "Nigeria", "Norway", "Oman", "Pakistan", "Palau", "Palestine", "Panama", "Paraguay", "Peru", "Philippines", "Poland", "Portugal", "Qatar", "Romania", "Russian_Federation", "Rwanda", "Saint_Kitts_and_Nevis", "Samoa", "Sao_Tome_and_Principe", "Saudi_Arabia", "Senegal", "Serbia", "Sierra_Leone", "Singapore", "Slovakia", "Slovenia", "South_Africa", "South_Sudan", "Spain", "Sri_Lanka", "Sudan", "Suriname", "Sweden", "Switzerland", "Syria", "Tajikistan", "Tanzania", "Thailand", "Togo", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Turkmenistan", "Uganda", "Ukraine", "United _Arab_Emirates", "United_Kingdom", "United_States", "Uruguay", "Uzbekistan", "Venezuela", "Vietnam", "Yemen", "Zambia", "Zimbabwe"], "y": [0.48, 0.77, 0.74, 0.82, 0.74, 0.93, 0.9, 0.74, 0.81, 0.8, 0.57, 0.8, 0.9, 0.49, 0.58, 0.66, 0.74, 0.68, 0.74, 0.85, 0.79, 0.39, 0.41, 0.64, 0.55, 0.53, 0.91, 0.36, 0.39, 0.82, 0.72, 0.72, 0.57, 0.77, 0.45, 0.82, 0.77, 0.85, 0.86, 0.92, 0.46, 0.71, 0.73, 0.68, 0.59, 0.42, 0.86, 0.56, 0.43, 0.72, 0.91, 0.89, 0.68, 0.44, 0.75, 0.93, 0.57, 0.85, 0.43, 0.44, 0.91, 0.83, 0.91, 0.6, 0.68, 0.78, 0.66, 0.9, 0.87, 0.72, 0.9, 0.73, 0.78, 0.56, 0.89, 0.8, 0.65, 0.82, 0.75, 0.42, 0.74, 0.91, 0.83, 0.89, 0.74, 0.51, 0.46, 0.78, 0.69, 0.41, 0.85, 0.5, 0.77, 0.76, 0.62, 0.8, 0.64, 0.41, 0.55, 0.55, 0.92, 0.9, 0.63, 0.34, 0.51, 0.94, 0.8, 0.54, 0.78, 0.69, 0.77, 0.68, 0.73, 0.68, 0.84, 0.83, 0.84, 0.8, 0.8, 0.5, 0.76, 0.7, 0.55, 0.84, 0.48, 0.77, 0.41, 0.92, 0.84, 0.88, 0.66, 0.39, 0.87, 0.76, 0.48, 0.71, 0.91, 0.94, 0.63, 0.64, 0.51, 0.73, 0.47, 0.72, 0.77, 0.72, 0.76, 0.69, 0.49, 0.74, 0.85, 0.9, 0.92, 0.79, 0.68, 0.77, 0.67, 0.5, 0.57, 0.5]}, {"line": {"color": "green"}, "name": "HDI in 2017", "opacity": 0.8, "type": "scatter", "x": ["Afghanistan", "Albania", "Algeria", "Argentina", "Armenia", "Australia", "Austria", "Azerbaijan", "Bahamas", "Bahrain", "Bangladesh", "Belarus", "Belgium", "Benin", "Bhutan", "Bolivia ", "Bosnia_and_Herzegovina", "Botswana", "Brazil", "Brunei_Darussalam", "Bulgaria", "Burkina_Faso", "Burundi", "Cabo_Verde", "Cambodia", "Cameroon", "Canada", "Central_African", "Chad", "Chile", "China", "Colombia", "Congo", "Costa_Rica", "C\u00f4te_d_Ivoire", "Croatia", "Cuba", "Cyprus", "Czechia", "Denmark", "Djibouti", "Dominican_Republic", "Ecuador", "Egypt", "Equatorial_Guinea", "Eritrea", "Estonia", "Eswatini ", "Ethiopia", "Fiji", "Finland", "France", "Gabon", "Gambia", "Georgia", "Germany", "Ghana", "Greece", "Guinea", "Guinea_Bissau", "Hong Kong", "Hungary", "Iceland", "India", "Indonesia", "Iran", "Iraq", "Ireland", "Italy", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Kore ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.777

# %% [markdown]
# ### How many incresed and how many decresed ?

# %%
fig, ax = plt.subplots(figsize=(4,6), subplot_kw=dict(aspect="equal"))

r = ["4 decresed in HDI rate","156 incresed in HDI rate",]

data = [4, 156]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40,colors=cols)

bbox_props = dict(boxstyle="square,pad=0.4", fc="w", ec="k", lw=3)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(r[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Countries with increase HDI vs decrese HDI")

plt.show()

# %% [markdown]
# #### Out of 160, 156 countries incresed in their HDI rate, while only 4 reduced

# %% [markdown]
# ## let's see the highest change in rates countries between 2012-2017

# %%
sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

top_15_2017 = hdi[hdi['change_rate']>0].sort_values(by='change_rate', ascending=False).head(10)
top_15_2017.plot('Country', 'change_rate', kind='bar', figsize=(14,8), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('change_rate')
plt.title('Highest incresed in the change rate countries ')
# Out:
# Cote divoire and zimbabwe were working hard to increse the HDI rate !

# %% [markdown]
# #### Cote d'ivoire and zimbabwe were working hard to increse the HDI rate !

# %% [markdown]
# ### Now, let's see the lowest countries with change rates between 2012-2017

# %%
sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

bot_15_2017 = hdi[hdi['change_rate']>0].sort_values(by='change_rate').head(10)
bot_15_2017.plot('Country', 'change_rate', kind='bar', figsize=(13,8), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('change_rate')
plt.title('Lowest incresed in the change rate countries ')
# Out:
# Text(0.5, 1.0, 'Lowest incresed in the change rate countries ')

# %% [markdown]
# ### These countries had little no change in thier HDI

# %% [markdown]
# ------

# %% [markdown]
# ## Now i know the 156 countries that incresed in the HDI, lets look up their PM2.5 rates

# %%
#taking the incresed HDI countries for the next stage and look up the pm2.5 data for them.
pm_countries = pd.DataFrame()
pm_countries['countries'] = subset_high_C.index
#pm_countries.to_csv('pm_countries.csv')

# %% [markdown]
# _________________________

# %% [markdown]
# ______________

# %% [markdown]
# # Part Two - PM2.5 air polution
# i got the data for the countries that passed the first critic overview, however,<font color="red">,there was 20 Countries with NO PM2.5 data </font>
# - PM2.5 air pollution fetched is masuerd by the mean annual exposure (micrograms per cubic meter)
# - what i am going to check ?
#  - First, does all incresed  HDI countries contrubuited to the envairoment positivly ?
#  - second, how many ararbic countries contruibitd positivly ?
#
#    lets see !

# %% [markdown]
# ###  Import the P2.5 data

# %%
air = pd.read_csv('pm2.5_.csv').round(3)

# %%
air.shape
# Out:
# (136, 11)

# %%
air = air.set_index(['Country_'])

# %% [markdown]
# ### Define the arabic countries

# %%
arabic_countries=['Jordan','United Arab Emirates','Tunisia','Sudan','Kuwait','South Sudan','Iraq','Saudi Arabia','Qatar','Oman','Morocco','Mauritania','Egypt, Arab Rep.','Bahrain','Algeria']

# %%
test =[]
for i in air.index:
    if i in arabic_countries:
        test.append(1)
    else:
        test.append(0)

# %%
air['arabic'] = test

# %%
arabic = air[air['arabic']==1]

# %% [markdown]
# ###  Massure the change rate betweent 2012-2017

# %%
air['change_rate'] =  (air.pm_2017-air.pm_2012)/air.pm_2012 *100

# %%
air['diffreance'] =  (air.pm_2017-air.pm_2012)

# %% [markdown]
# ####  Distinguish between the incresed pm2.5 and the decrese pm2.5

# %%
incresed_p = air[(air['change_rate'] >= 0)]

# %%
incresed_p.index.value_counts().sum() # countries with incresed pm2.5 rate
# Out:
# 45

# %%
arabic_incresed = incresed_p[incresed_p['arabic']==1]

# %%
decresed_P = air[(air['change_rate'] < 0)].round(2)

# %%
decresed_P.index.value_counts().sum()# countries with decresed pm2.5 rate
# Out:
# 91

# %%
# Idenitify highest decrese in pm2.5 pollution

# %%
decresed_P # top 10 in the highest decrese.
# Out:
#                        code  pm_2010  pm_2011  pm_2012  pm_2013  pm_2014  \
# Country_
# Afghanistan             AFG    65.25    66.84    66.02    61.37    59.01
# Albania                 ALB    21.28    22.77    20.58    19.94    18.88
# Argentina               ARG    16.86    17.38    16.14    15.60    14.47
# Armenia                 ARM    37.53    38.61    37.18    34.94    33.09
# Australia               AUS    10.62    11.05    10.54     9.99     9.49
# Austria                 AUT    15.15    15.57    14.28    14.08    13.38
# Azerbaijan              AZE    23.05    23.63    22.18    22.28    20.71
# Bahamas, The            BHS    21.11    21.77    20.32    19.91    18.50
# Bangladesh              BGD    70.76    70.21    70.79    65.64    68.40
# Belarus                 BLR    23.32    22.91    21.65    20.59    19.77
# Belgium                 BEL    16.01    15.70    14.74    14.02    13.23
# Bhutan                  BTN    43.96    43.07    42.93    41.88    40.84
# Bolivia                 BOL    29.57    27.90    26.39    26.09    24.82
# Bosnia_and_Herzegovina  BIH    32.30    34.19    31.77    30.45    28.78
# Brazil                  BRA    15.96    15.91    15.28    14.61    13.99
# Bulgaria                BGR    22.76    24.30    22.64    21.00    20.74
# Burundi                 BDI    38.38    38.24    41.01    39.97    39.39
# Cambodia                KHM    31.34    30.92    31.28    30.34    28.58
# Canada                  CAN     8.38     8.62     8.11     7.79     7.43
# Chile                   CHL    25.89    27.25    25.05    23.94    22.87
# China                   CHN    69.48    70.54    63.83    65.52    59.77
# Colombia                COL    21.50    21.37    20.54    19.22    18.34
# Costa Rica              CRI    19.27    19.70    19.34    18.34    17.54
# Croatia                 HRV    21.34    21.97    20.20    19.59    18.43
# Cuba                    CUB    23.93    24.79    23.24    22.85    21.30
# Cyprus                  CYP    20.08    20.09    19.23    18.68    18.29
# Czech Republic          CZE    20.68    20.08    18.74    18.00    17.39
# Denmark                 DNK    11.93    12.66    11.12    10.82    11.07
# Dominican Republic      DOM    16.87    17.30    16.15    15.40    14.19
# Estonia                 EST     8.52     8.44     7.81     7.48     7.71
# ...                     ...      ...      ...      ...      ...      ...
# New Zealand             NZL     7.15     7.42     6.84     6.78     6.36
# Norway                  NOR     8.34     8.85     7.92     7.63     7.67
# Pakistan                PAK    68.00    68.54    62.38    61.02    59.52
# Paraguay                PRY    15.10    14.60    13.95    12.93    12.64
# Peru                    PER    31.50    31.57    30.49    29.74    27.58
# Philippines             PHL    23.59    22.76    22.55    21.22    20.26
# Poland                  POL    27.18    26.37    24.26    22.93    22.21
# Portugal                PRT    10.08    10.36     9.48     9.43     8.78
# Romania                 ROU    17.06    17.64    16.32    15.37    15.01
# Russian Federation      RUS    19.48    19.19    18.30    17.80    16.58
# Rwanda                  RWA    41.44    42.68    44.56    44.41    42.21
# Serbia                  SRB    29.10    31.03    28.58    27.43    26.49
# Singapore               SGP    20.61    19.35    20.89    18.71    17.41
# Slovak Republic         SVK    21.69    21.77    19.76    19.32    18.30
# Slovenia                SVN    18.68    19.51    17.67    17.57    16.63
# South Africa            ZAF    27.14    26.56    26.58    26.73    26.72
# Spain                   ESP    11.35    12.04    11.15    10.74    10.07
# Sri Lanka               LKA    31.03    31.23    30.08    28.90    26.92
# Sweden                  SWE     7.21     7.39     6.63     6.43     6.96
# Switzerland             CHE    12.92    13.05    12.26    11.82    11.39
# Tajikistan              TJK    50.40    54.32    48.99    49.55    46.48
# Tanzania                TZA    28.61    28.73    29.97    29.36    28.87
# Thailand                THA    31.56    31.61    31.52    31.18    29.36
# Ukraine                 UKR    23.52    23.97    22.33    21.53    20.49
# United Kingdom          GBR    12.30    12.85    11.81    11.62    10.80
# Uruguay                 URY    11.03    11.47    10.57    10.46     9.93
# Uzbekistan              UZB    32.08    33.99    31.66    30.80    28.90
# Vietnam                 VNM    39.36    38.49    37.23    36.84    34.90
# Zambia                  ZMB    28.84    28.99    29.74    29.11    28.49
# Zimbabwe                ZWE    23.23    23.07    23.20    23.11    22.81
#
#                         pm_2015  pm_2016  pm_2017                 Country  \
# Country_
# Afghanistan               61.25    56.29    56.91             Afghanistan
# Albania                   19.51    18.19    18.20                 Albania
# Argentina                 14.63    13.75    13.31               Argentina
# Armenia                   34.88    32.23    32.53                 Armenia
# Australia                  9.32     8.62     8.55               Australia
# Austria                   13.54    12.60    12.48                 Austria
# Azerbaijan                21.41    20.21    19.93              Azerbaijan
# Bahamas, The              18.89    17.65    17.37            Bahamas, The
# Bangladesh                66.97    60.13    60.85              Bangladesh
# Belarus                   20.08    18.88    18.77                 Belarus
# Belgium                   13.57    12.83    12.89                 Belgium
# Bhutan                    39.82    37.22    37.93                  Bhutan
# Bolivia                   22.48    21.39    21.57                 Bolivia
# Bosnia_and_Herzegovina    29.62    27.59    27.75  Bosnia_and_Herzegovina
# Brazil                    13.60    12.66    12.71                  Brazil
# Bulgaria                  20.78    19.28    19.15                Bulgaria
# Burundi                   38.43    38.65    38.90                 Burundi
# Cambodia                  26.77    25.20    25.61                Cambodia
# Canada                     7.15     6.55     6.43                  Canada
# Chile                     22.57    20.88    21.04                   Chile
# China                     59.06    52.21    52.66                   China
# Colombia                  17.30    16.58    16.53                Colombia
# Costa Rica                16.88    15.66    15.73              Costa Rica
# Croatia                   19.21    17.79    17.90                 Croatia
# Cuba                      20.86    19.74    19.71                    Cuba
# Cyprus                    19.10    16.96    17.29                  Cyprus
# Czech Republic            17.42    16.10    16.07          Czech Republic
# Denmark                   10.66    10.10    10.03                 Denmark
# Dominican Republic        14.86    13.69    13.73      Dominican Republic
# Estonia                    7.00     6.82     6.73                 Estonia
# ...                         ...      ...      ...                     ...
# New Zealand                6.33     5.99     5.96             New Zealand
# Norway                     7.24     6.96     6.96                  Norway
# Pakistan                  60.09    58.63    58.28                Pakistan
# Paraguay                  13.04    11.65    11.91                Paraguay
# Peru                      26.04    25.54    24.79                    Peru
# Philippines               19.58    18.23    18.07             Philippines
# Poland                    22.69    20.98    20.88                  Poland
# Portugal                   8.82     8.05     8.16                Portugal
# Romania                   15.43    14.54    14.61                 Romania
# Russian Federation        17.02    16.22    16.16      Russian Federation
# Rwanda                    42.61    42.84    43.21                  Rwanda
# Serbia                    26.95    24.78    24.73                  Serbia
# Singapore                 20.66    18.80    19.08               Singapore
# Slovak Republic           18.80    17.35    17.56         Slovak Republic
# Slovenia                  17.13    15.91    16.02                Slovenia
# South Africa              26.11    25.14    25.10            South Africa
# Spain                     10.45     9.70     9.70                   Spain
# Sri Lanka                 25.34    14.02    11.10               Sri Lanka
# Sweden                     6.32     6.11     6.18                  Sweden
# Switzerland               11.16    10.34    10.30             Switzerland
# Tajikistan                47.79    43.38    46.15              Tajikistan
# Tanzania                  28.24    28.44    29.08                Tanzania
# Thailand                  27.34    26.26    26.26                Thailand
# Ukraine                   21.25    20.62    20.31                 Ukraine
# United Kingdom            10.76    10.50    10.47          United Kingdom
# Uruguay                    9.66     9.20     9.28                 Uruguay
# Uzbekistan                30.39    27.81    28.46              Uzbekistan
# Vietnam                   32.47    30.24    29.63                 Vietnam
# Zambia                    28.38    27.36    27.44                  Zambia
# Zimbabwe                  21.73    21.73    22.25                Zimbabwe
#
#                         arabic  change_rate  diffreance
# Country_
# Afghanistan                  0       -13.80       -9.11
# Albania                      0       -11.55       -2.38
# Argentina                    0       -17.50       -2.82
# Armenia                      0       -12.52       -4.66
# Australia                    0       -18.86       -1.99
# Austria                      0       -12.63       -1.80
# Azerbaijan                   0       -10.15       -2.25
# Bahamas, The                 0       -14.51       -2.95
# Bangladesh                   0       -14.05       -9.95
# Belarus                      0       -13.30       -2.88
# Belgium                      0       -12.58       -1.86
# Bhutan                       0       -11.66       -5.01
# Bolivia                      0       -18.27       -4.82
# Bosnia_and_Herzegovina       0       -12.67       -4.02
# Brazil                       0       -16.87       -2.58
# Bulgaria                     0       -15.44       -3.50
# Burundi                      0        -5.16       -2.12
# Cambodia                     0       -18.12       -5.67
# Canada                       0       -20.71       -1.68
# Chile                        0       -16.01       -4.01
# China                        0       -17.49      -11.16
# Colombia                     0       -19.53       -4.01
# Costa Rica                   0       -18.67       -3.61
# Croatia                      0       -11.39       -2.30
# Cuba                         0       -15.21       -3.53
# Cyprus                       0       -10.04       -1.93
# Czech Republic               0       -14.26       -2.67
# Denmark                      0        -9.77       -1.09
# Dominican Republic           0       -15.03       -2.43
# Estonia                      0       -13.81       -1.08
# ...                        ...          ...         ...
# New Zealand                  0       -12.87       -0.88
# Norway                       0       -12.21       -0.97
# Pakistan                     0        -6.56       -4.10
# Paraguay                     0       -14.62       -2.04
# Peru                         0       -18.72       -5.71
# Philippines                  0       -19.87       -4.48
# Poland                       0       -13.95       -3.39
# Portugal                     0       -13.96       -1.32
# Romania                      0       -10.45       -1.70
# Russian Federation           0       -11.71       -2.14
# Rwanda                       0        -3.03       -1.35
# Serbia                       0       -13.50       -3.86
# Singapore                    0        -8.66       -1.81
# Slovak Republic              0       -11.14       -2.20
# Slovenia                     0        -9.32       -1.65
# South Africa                 0        -5.55       -1.48
# Spain                        0       -13.02       -1.45
# Sri Lanka                    0       -63.10      -18.98
# Sweden                       0        -6.68       -0.44
# Switzerland                  0       -15.97       -1.96
# Tajikistan                   0        -5.79       -2.84
# Tanzania                     0        -2.98       -0.89
# Thailand                     0       -16.71       -5.27
# Ukraine                      0        -9.04       -2.02
# United Kingdom               0       -11.35       -1.34
# Uruguay                      0       -12.23       -1.29
# Uzbekistan                   0       -10.13       -3.21
# Vietnam                      0       -20.42       -7.60
# Zambia                       0        -7.75       -2.30
# Zimbabwe                     0        -4.08       -0.95
#
# [91 rows x 13 columns]

# %%
# outside reserch to do - find out what those countries were doing to get this decreese in the pm2.5

# %%
arabic_decresed = decresed_P[decresed_P['arabic']==1]

# %%
arabic_decresed
# Out:
#          code  pm_2010  pm_2011  pm_2012  pm_2013  pm_2014  pm_2015  pm_2016  \
# Country_
# Iraq      IRQ    68.71    66.36    66.84    63.80    56.57    66.26    63.96
# Kuwait    KWT    62.74    62.82    64.07    62.61    55.62    65.41    60.84
#
#           pm_2017 Country  arabic  change_rate  diffreance
# Country_
# Iraq        61.64    Iraq       1        -7.79       -5.21
# Kuwait      60.74  Kuwait       1        -5.19       -3.33

# %% [markdown]
# ### lets arrange the first theory findings in a data frame !

# %%
F_Theory= pd.DataFrame()

# %%
F_Theory['Incresed%'] = [incresed_p.index.value_counts().sum()/air.index.value_counts().sum() *100]

# %%
F_Theory['Decresed%'] = [decresed_P.index.value_counts().sum()/air.index.value_counts().sum()*100]

# %%
F_Theory['Incresed_arabic']= arabic_incresed.index.value_counts().sum()
F_Theory['Decresed_arabic'] = arabic_decresed.index.value_counts().sum()

# %%
F_Theory
# Out:
#    Incresed%  Decresed%  Incresed_arabic  Decresed_arabic
# 0  33.088235  66.911765               13                2

# %% [markdown]
# First Theory was proven true :
#     - Not all countries contrubuit postivily with the HDI incresemnt
#     - 13!! out of 15 arabic countries contuorbted negetivly !

# %% [markdown]
# ### 91 countries only contirubated +ve-ly towards the enviroment, of which only 2 were arabic.

# %% [markdown]
#    --------------------

# %% [markdown]
# # Visualzation for part two

# %% [markdown]
# ### General overview on the pm2.5 changes between 2012-2017

# %%
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=air['Country'],
                y=air['pm_2012'],
                name="PM2.5 in 2012",
                line_color='blue',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=air['Country'],
                y=air['pm_2017'],
                name="PM2.5 in 2017",
                line_color='green',
                opacity=0.8))
# Use date string to set xaxis range
title_text="Changes Between 2012-2017"
fig.show()
# Out:
# <div>
#
#
#             <div id="242a649b-62a1-4da0-8955-5c4e8156396f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("242a649b-62a1-4da0-8955-5c4e8156396f")) {
#                     Plotly.newPlot(
#                         '242a649b-62a1-4da0-8955-5c4e8156396f',
#                         [{"line": {"color": "blue"}, "name": "PM2.5 in 2012", "opacity": 0.8, "type": "scatter", "x": ["Afghanistan", "Albania", "Algeria", "Argentina", "Armenia", "Australia", "Austria", "Azerbaijan", "Bahamas, The", "Bahrain", "Bangladesh", "Belarus", "Belgium", "Benin", "Bhutan", "Bolivia", "Bosnia_and_Herzegovina", "Brazil", "Bulgaria", "Burkina Faso", "Burundi", "Cabo Verde", "Cambodia", "Cameroon", "Canada", "Central African Republic", "Chad", "Chile", "China", "Colombia", "Congo, Rep.", "Costa Rica", "Cote d'Ivoire", "Croatia", "Cuba", "Cyprus", "Czech Republic", "Denmark", "Djibouti", "Dominican Republic", "Egypt, Arab Rep.", "Equatorial Guinea", "Eritrea", "Estonia", "Ethiopia", "Fiji", "Finland", "France", "Gabon", "Gambia, The", "Georgia", "Germany", "Ghana", "Greece", "Guinea", "Guinea-Bissau", "Hungary", "Iceland", "India", "Indonesia", "Iran, Islamic Rep.", "Iraq", "Ireland", "Italy", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Korea, Rep.", "Kuwait", "Kyrgyz Republic", "Lebanon", "Liberia", "Lithuania", "Luxembourg", "Madagascar", "Malaysia", "Maldives", "Mali", "Malta", "Mauritania", "Mauritius", "Mexico", "Micronesia, Fed. Sts.", "Montenegro", "Morocco", "Mozambique", "Myanmar", "Nepal", "Netherlands", "New Zealand", "Niger", "Nigeria", "Norway", "Oman", "Pakistan", "Paraguay", "Peru", "Philippines", "Poland", "Portugal", "Qatar", "Romania", "Russian Federation", "Rwanda", "Sao Tome and Principe", "Saudi Arabia", "Senegal", "Serbia", "Sierra Leone", "Singapore", "Slovak Republic", "Slovenia", "South Africa", "South Sudan", "Spain", "Sri Lanka", "Sudan", "Sweden", "Switzerland", "Tajikistan", "Tanzania", "Thailand", "Togo", "Tunisia", "Turkey", "Uganda", "Ukraine", "United Arab Emirates", "United Kingdom", "Uruguay", "Uzbekistan", "Vietnam", "Zambia", "Zimbabwe"], "y": [66.023, 20.578, 33.367, 16.135, 37.184, 10.537, 14.282, 22.181, 20.317, 70.287, 70.794, 21.646, 14.742, 31.992, 42.932, 26.39, 31.773, 15.285, 22.645, 38.784, 41.011, 32.941, 31.284, 62.777, 8.107, 53.359, 58.675, 25.047, 63.827, 20.537, 43.49, 19.335, 22.494, 20.202, 23.24, 19.225, 18.743, 11.116, 39.943, 16.153, 72.791, 45.232, 46.134, 7.811, 35.974, 12.852, 6.601, 13.835, 40.814, 30.729, 25.003, 13.578, 28.897, 18.421, 22.99, 27.09, 17.53, 7.337, 88.169, 18.17, 38.542, 66.842, 9.523, 18.105, 15.46, 13.129, 33.006, 14.481, 29.372, 27.916, 64.071, 25.49, 30.108, 16.288, 13.785, 11.776, 22.164, 19.182, 11.157, 34.7, 15.397, 42.344, 15.246, 25.982, 12.974, 24.68, 27.79, 22.868, 42.523, 96.963, 13.812, 6.836, 72.545, 56.13, 7.925, 40.733, 62.377, 13.948, 30.494, 22.55, 24.264, 9.485, 89.247, 16.316, 18.304, 44.561, 25.916, 85.513, 36.168, 28.585, 20.101, 20.886, 19.765, 17.67, 26.577, 43.974, 11.15, 30.084, 49.686, 6.628, 12.261, 48.99, 29.97, 31.525, 31.369, 32.816, 41.921, 49.627, 22.329, 39.277, 11.814, 10.567, 31.662, 37.227, 29.742, 23.198]}, {"line": {"color": "green"}, "name": "PM2.5 in 2017", "opacity": 0.8, "type": "scatter", "x": ["Afghanistan", "Albania", "Algeria", "Argentina", "Armenia", "Australia", "Austria", "Azerbaijan", "Bahamas, The", "Bahrain", "Bangladesh", "Belarus", "Belgium", "Benin", "Bhutan", "Bolivia", "Bosnia_and_Herzegovina", "Brazil", "Bulgaria", "Burkina Faso", "Burundi", "Cabo Verde", "Cambodia", "Cameroon", "Canada", "Central African Republic", "Chad", "Chile", "China", "Colombia", "Congo, Rep.", "Costa Rica", "Cote d'Ivoire", "Croatia", "Cuba", "Cyprus", "Czech Republic", "Denmark", "Djibouti", "Dominican Republic", "Egypt, Arab Rep.", "Equatorial Guinea", "Eritrea", "Estonia", "Ethiopia", "Fiji", "Finland", "France", "Gabon", "Gambia, The", "Georgia", "Germany", "Ghana", "Greece", "Guinea", "Guinea-Bissau", "Hungary", "Iceland", "India", "Indonesia", "Iran, Islamic Rep.", "Iraq", "Ireland", "Italy", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Korea, Rep.", "Kuwait", "Kyrgyz Republic", "Lebanon", "Liberia", "Lithuania", "Luxembourg", "Madagascar", "Malaysia", "Maldives", "Mali", ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2

# %% [markdown]
# ### Count of the countries that incresed vs decresed

# %%
fig, ax = plt.subplots(figsize=(4,6), subplot_kw=dict(aspect="equal"))

r = ["45 incresed in PM2.5 rate","91 decresed in PM2.5 rate"]

data = [45, 91]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40,colors=cols)

bbox_props = dict(boxstyle="square,pad=0.4", fc="w", ec="k", lw=3)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(r[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Countries with increase PM2.5 vs decrese PM2.5")

plt.show()

# %% [markdown]
# ### Highest Incresed In The Change Rate Of PM2.5

# %%
sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

bot_15_2017 = air[air['change_rate']>0].sort_values(by='change_rate',ascending=False).head(10)
bot_15_2017.plot('Country', 'change_rate', kind='bar', figsize=(14,10), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('Change rate')
plt.title('Highest Incresed In The Change Rate Of PM2.5 ')
# Out:
# Text(0.5, 1.0, 'Highest Incresed In The Change Rate Of PM2.5 ')

# %% [markdown]
# #### These countries had the highest increase of the pm2.5 polloution !

# %% [markdown]
# ### Highest Decraese In The PM2.5 Change Rate

# %%
sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

bot_15_2017 = air[air['change_rate']<0].sort_values(by='change_rate').head(10)
bot_15_2017.plot('Country', 'change_rate', kind='bar', figsize=(13,8), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('Change rate')
plt.title('Highest Decraese In The PM2.5 Change Rate')
# Out:
# Text(0.5, 1.0, 'Highest Decraese In The PM2.5 Change Rate')

# %% [markdown]
# ### Highest Decraese In The PM2.5 points

# %%
sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

bot_15_2017 = air[air['diffreance']<0].sort_values(by='diffreance').head(10)
bot_15_2017.plot('Country', 'diffreance', kind='bar', figsize=(13,8), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('diffreance')
plt.title('Highest Decraese In The PM2.5 Diffrence in point')
# Out:
# Text(0.5, 1.0, 'Highest Decraese In The PM2.5 Diffrence in point')

# %% [markdown]
# ### These countries had the highest decrease on the pm2.5 , they were doing great regarding dcreseing it !

# %%
import plotly.graph_objects as go

labels = ['Incresed in PM2.5 rate','Decresed in PM2.5 rate']
values = [13, 2]

# pull is given as a fraction of the pie radius
fig = go.Figure(data=[go.Pie(labels=labels, values=values, pull=[0.2, 0.2, 0.2, 0.2],marker_colors=cols)] )
fig.update_layout(title_text='Arabic Countries')
fig.show()
# Out:
# <div>
#
#
#             <div id="eb731de1-19eb-478d-b496-a242c874a7b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eb731de1-19eb-478d-b496-a242c874a7b4")) {
#                     Plotly.newPlot(
#                         'eb731de1-19eb-478d-b496-a242c874a7b4',
#                         [{"labels": ["Incresed in PM2.5 rate", "Decresed in PM2.5 rate"], "marker": {"colors": ["#B2E0F0", "#174147", "#BFD1D7"]}, "pull": [0.2, 0.2, 0.2, 0.2], "type": "pie", "values": [13, 2]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ----------

# %% [markdown]
# ## Now lets take the 91 countries with postive contribution towards envaromental health for the next theory :
# - personal saftey

# %%
ps_countries = pd.DataFrame()
ps_countries['countries'] = decresed_P.index
#pm_countries.to_csv('ps_countriess.csv')

# %% [markdown]
# _________

# %% [markdown]
# _______

# %% [markdown]
# # Third Part : Personal Saftey Index

# %% [markdown]
# Personal saftey index is a percentage that masuer a calculated scores of Homicide rate,Perceived criminality,Political killings and torture,Traffic deaths, how ever, there was 3 countries with no PSI data

# %% [markdown]
# - what i am going to check ?
#  - First, does all incresed  HDI countries contrubuited to the personal saftey index positivly ?
#    lets see !

# %%
ps = pd.read_csv('personal_saftey.csv')

# %%
ps.set_index('Country').head(1)
# Out:
#             Code  ps_2013  ps_2014  ps_2015  ps_2016  ps_2017  ps_2018
# Country
# Afghanistan  AFG     45.6    43.88     44.4    44.23    45.63    46.85

# %%
ps['Personl_change_rate']= (ps['ps_2018']- ps['ps_2013'])/ps['ps_2013']*100

# %%
ps['diffrence_']= (ps['ps_2018']- ps['ps_2013'])

# %%
decrese_ps = ps[(ps['Personl_change_rate'] <0)] # countries with decresed peronal saftey
decrese_ps.shape
# Out:
# (35, 10)

# %%
incresed_ps = ps[(ps['Personl_change_rate'] >0)] # countries with decresed peronal saftey
incresed_ps.shape
# Out:
# (54, 10)

# %%
incresed_ps.sort_values(by="Personl_change_rate",ascending=False) # top 10 in the +ve change rate
# Out:
#                Country Code  ps_2013  ps_2014  ps_2015  ps_2016  ps_2017  \
# 76           Sri Lanka  LKA    64.67    65.86    69.32    71.79    72.32
# 47          Kyrgyzstan  KGZ    61.72    64.10    65.35    66.10    64.61
# 69              Rwanda  RWA    54.82    62.16    61.14    56.57    56.52
# 36             Iceland  ISL    88.28    90.31    90.34    89.29    94.11
# 45  Korea, Republic of  KOR    85.42    85.79    86.06    86.24    92.62
# 11             Bolivia  BOL    63.72    64.14    66.49    66.06    68.52
# 10              Bhutan  BTN    79.48    79.58    81.05    81.17    83.83
# 17              Canada  CAN    85.55    85.98    86.16    86.08    90.99
# 42               Japan  JPN    90.34    90.44    90.52    90.49    96.26
# 4            Australia  AUS    87.25    87.45    87.41    87.34    92.62
# 71           Singapore  SGP    90.80    91.27    90.89    91.18    96.88
# 59         New Zealand  NZL    87.19    87.41    87.18    87.26    92.64
# 8              Belarus  BLR    69.00    69.77    70.21    70.81    72.09
# 43          Kazakhstan  KAZ    62.53    63.71    64.73    66.78    67.17
# 60              Norway  NOR    86.04    89.91    88.87    89.98    90.26
# 48           Lithuania  LTU    71.94    72.20    72.48    74.41    74.36
# 54              Mexico  MEX    51.75    52.85    53.54    54.37    54.40
# 62            Paraguay  PRY    63.88    63.92    64.84    66.10    66.05
# 2            Argentina  ARG    63.42    63.45    62.67    63.55    63.30
# 38                Iraq  IRQ    48.60    46.66    46.41    48.86    49.46
# 28             Estonia  EST    76.07    76.46    77.27    78.36    78.13
# 53           Mauritius  MUS    81.13    81.94    81.48    83.51    81.39
# 0          Afghanistan  AFG    45.60    43.88    44.40    44.23    45.63
# 34              Greece  GRC    79.02    79.68    79.83    79.79    81.23
# 87              Zambia  ZMB    62.17    63.36    63.85    60.06    60.61
# 66            Portugal  PRT    86.71    86.74    86.63    87.96    87.89
# 27  Dominican Republic  DOM    54.13    54.22    54.30    54.60    54.14
# 29                Fiji  FJI    74.40    75.09    76.19    76.29    76.28
# 63                Peru  PER    62.56    61.90    64.05    64.21    64.15
# 37           Indonesia  IDN    75.15    75.61    76.88    76.96    76.88
# 40               Italy  ITA    74.67    74.92    75.19    75.10    75.62
# 14            Bulgaria  BGR    77.72    77.51    77.98    77.85    77.48
# 44               Kenya  KEN    57.89    58.32    58.66    58.65    57.25
# 73            Slovenia  SVN    87.66    88.17    89.07    88.08    87.66
# 85          Uzbekistan  UZB    62.88    62.91    62.71    62.66    67.70
# 20            Colombia  COL    53.55    53.89    54.01    55.79    55.63
# 39             Ireland  IRL    88.09    87.57    87.81    87.95    89.35
# 68              Russia  RUS    52.58    52.07    52.50    52.62    53.38
# 19               China  CHN    61.18    61.49    62.94    63.19    63.35
# 65              Poland  POL    85.56    86.30    87.15    86.34    86.11
# 30             Finland  FIN    85.99    86.85    86.77    86.92    87.04
# 58         Netherlands  NLD    89.08    89.15    89.54    89.59    89.87
# 67             Romania  ROU    77.91    77.69    78.10    78.48    78.29
# 50            Malaysia  MYS    74.34    74.06    73.45    73.66    74.71
# 72            Slovakia  SVK    84.65    85.87    85.58    85.62    86.94
# 74        South Africa  ZAF    49.76    50.11    51.32    51.28    50.41
# 5              Austria  AUT    88.09    88.14    88.79    89.43    89.51
# 25      Czech Republic  CZE    87.64    87.28    87.74    87.76    87.61
# 80            Tanzania  TZA    65.76    66.05    66.70    65.84    66.06
# 78         Switzerland  CHE    89.61    89.77    89.58    90.27    89.77
# 31              France  FRA    80.44    80.87    81.01    80.98    80.26
# 75               Spain  ESP    83.09    83.33    83.35    83.19    83.34
# 49          Luxembourg  LUX    82.21    82.31    84.41    82.50    82.54
# 26             Denmark  DNK    88.41    88.46    89.08    88.02    88.71
#
#     ps_2018  Personl_change_rate  diffrence_
# 76    73.28            13.313747        8.61
# 47    69.08            11.924822        7.36
# 69    60.80            10.908428        5.98
# 36    96.13             8.892161        7.85
# 45    92.74             8.569422        7.32
# 11    68.63             7.705587        4.91
# 10    85.38             7.423251        5.90
# 17    91.42             6.861485        5.87
# 42    96.32             6.619438        5.98
# 4     92.88             6.452722        5.63
# 71    96.64             6.431718        5.84
# 59    92.37             5.941048        5.18
# 8     72.86             5.594203        3.86
# 43    65.80             5.229490        3.27
# 60    90.03             4.637378        3.99
# 48    74.79             3.961635        2.85
# 54    53.68             3.729469        1.93
# 62    66.17             3.584847        2.29
# 2     65.50             3.279722        2.08
# 38    50.13             3.148148        1.53
# 28    78.18             2.773761        2.11
# 53    83.38             2.773327        2.25
# 0     46.85             2.741228        1.25
# 34    81.16             2.708175        2.14
# 87    63.70             2.460994        1.53
# 66    88.80             2.410333        2.09
# 27    55.43             2.401626        1.30
# 29    76.17             2.379032        1.77
# 63    64.01             2.317775        1.45
# 37    76.84             2.248836        1.69
# 40    76.31             2.196331        1.64
# 14    79.17             1.865672        1.45
# 44    58.92             1.779236        1.03
# 73    89.14             1.688341        1.48
# 85    63.83             1.510814        0.95
# 20    54.34             1.475257        0.79
# 39    89.35             1.430355        1.26
# 68    53.33             1.426398        0.75
# 19    62.02             1.372998        0.84
# 65    86.66             1.285647        1.10
# 30    87.07             1.255960        1.08
# 58    90.08             1.122586        1.00
# 67    78.74             1.065332        0.83
# 50    75.05             0.955071        0.71
# 72    85.37             0.850561        0.72
# 74    50.18             0.844051        0.42
# 5     88.71             0.703826        0.62
# 25    88.25             0.696029        0.61
# 80    66.20             0.669100        0.44
# 78    90.09             0.535655        0.48
# 31    80.75             0.385380        0.31
# 75    83.39             0.361054        0.30
# 49    82.50             0.352755        0.29
# 26    88.68             0.305395        0.27

# %%
decrese_ps.sort_values(by="Personl_change_rate").head()
# Out:
#         Country Code  ps_2013  ps_2014  ps_2015  ps_2016  ps_2017  ps_2018  \
# 55   Montenegro  MNE    74.64    74.78    71.66    69.29    69.44    66.14
# 64  Philippines  PHL    59.42    59.64    58.89    55.59    55.37    52.86
# 15      Burundi  BDI    47.87    44.73    43.50    37.17    44.16    42.66
# 61     Pakistan  PAK    53.14    48.21    49.63    50.24    51.43    47.43
# 70       Serbia  SRB    79.43    80.18    73.86    73.91    73.47    71.58
#
#     Personl_change_rate  diffrence_
# 55           -11.387996       -8.50
# 64           -11.040054       -6.56
# 15           -10.883643       -5.21
# 61           -10.745201       -5.71
# 70            -9.882916       -7.85

# %% [markdown]
# Lets arrange the findings in a dataframe !

# %%
Theory_2 = pd.DataFrame()

# %%
Theory_2['Incresed%'] = [incresed_ps.index.value_counts().sum()/ps.index.value_counts().sum() *100]

# %%
Theory_2['Decresed%'] = [decrese_ps.index.value_counts().sum()/ps.index.value_counts().sum() *100]

# %%
Theory_2
# Out:
#    Incresed%  Decresed%
# 0  60.674157  39.325843

# %% [markdown]
# # Visualzation for part three

# %% [markdown]
# ### Generalview on the changes, over five years

# %%
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=ps['Country'],
                y=ps['ps_2013'],
                name="Personal Saftey Index in 2013",
                line_color='blue',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=ps['Country'],
                y=ps['ps_2017'],
                name="Personal Saftey Index in 2018",
                line_color='green',
                opacity=0.8))
# Use date string to set xaxis range
title_text="Changes Between 2013-2018"
fig.show()
# Out:
# <div>
#
#
#             <div id="95051dfe-0010-4ffd-9b5c-11bd04c38246" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("95051dfe-0010-4ffd-9b5c-11bd04c38246")) {
#                     Plotly.newPlot(
#                         '95051dfe-0010-4ffd-9b5c-11bd04c38246',
#                         [{"line": {"color": "blue"}, "name": "Personal Saftey Index in 2013", "opacity": 0.8, "type": "scatter", "x": ["Afghanistan", "Albania", "Argentina", "Armenia", "Australia", "Austria", "Azerbaijan", "Bangladesh", "Belarus", "Belgium", "Bhutan", "Bolivia", "Bosnia and Herzegovina", "Brazil", "Bulgaria", "Burundi", "Cambodia", "Canada", "Chile", "China", "Colombia", "Costa Rica", "Croatia", "Cuba", "Cyprus", "Czech Republic", "Denmark", "Dominican Republic", "Estonia", "Fiji", "Finland", "France", "Georgia", "Germany", "Greece", "Hungary", "Iceland", "Indonesia", "Iraq", "Ireland", "Italy", "Jamaica", "Japan", "Kazakhstan", "Kenya", "Korea, Republic of", "Kuwait", "Kyrgyzstan", "Lithuania", "Luxembourg", "Malaysia", "Maldives", "Malta", "Mauritius", "Mexico", "Montenegro", "Mozambique", "Myanmar", "Netherlands", "New Zealand", "Norway", "Pakistan", "Paraguay", "Peru", "Philippines", "Poland", "Portugal", "Romania", "Russia", "Rwanda", "Serbia", "Singapore", "Slovakia", "Slovenia", "South Africa", "Spain", "Sri Lanka", "Sweden", "Switzerland", "Tajikistan", "Tanzania", "Thailand", "Ukraine", "United Kingdom", "Uruguay", "Uzbekistan", "Vietnam", "Zambia", "Zimbabwe"], "y": [45.6, 75.44, 63.42, 76.25, 87.25, 88.09, 70.71, 64.6, 69.0, 84.78, 79.48, 63.72, 79.68, 54.23, 77.72, 47.87, 56.12, 85.55, 75.44, 61.18, 53.55, 69.93, 80.54, 73.98, 80.8, 87.64, 88.41, 54.13, 76.07, 74.4, 85.99, 80.44, 75.79, 88.38, 79.02, 79.88, 88.28, 75.15, 48.6, 88.09, 74.67, 56.87, 90.34, 62.53, 57.89, 85.42, 77.32, 61.72, 71.94, 82.21, 74.34, 74.71, 83.23, 81.13, 51.75, 74.64, 57.23, 64.26, 89.08, 87.19, 86.04, 53.14, 63.88, 62.56, 59.42, 85.56, 86.71, 77.91, 52.58, 54.82, 79.43, 90.8, 84.65, 87.66, 49.76, 83.09, 64.67, 89.4, 89.61, 70.39, 65.76, 59.14, 63.82, 82.86, 70.26, 62.88, 76.6, 62.17, 41.21]}, {"line": {"color": "green"}, "name": "Personal Saftey Index in 2018", "opacity": 0.8, "type": "scatter", "x": ["Afghanistan", "Albania", "Argentina", "Armenia", "Australia", "Austria", "Azerbaijan", "Bangladesh", "Belarus", "Belgium", "Bhutan", "Bolivia", "Bosnia and Herzegovina", "Brazil", "Bulgaria", "Burundi", "Cambodia", "Canada", "Chile", "China", "Colombia", "Costa Rica", "Croatia", "Cuba", "Cyprus", "Czech Republic", "Denmark", "Dominican Republic", "Estonia", "Fiji", "Finland", "France", "Georgia", "Germany", "Greece", "Hungary", "Iceland", "Indonesia", "Iraq", "Ireland", "Italy", "Jamaica", "Japan", "Kazakhstan", "Kenya", "Korea, Republic of", "Kuwait", "Kyrgyzstan", "Lithuania", "Luxembourg", "Malaysia", "Maldives", "Malta", "Mauritius", "Mexico", "Montenegro", "Mozambique", "Myanmar", "Netherlands", "New Zealand", "Norway", "Pakistan", "Paraguay", "Peru", "Philippines", "Poland", "Portugal", "Romania", "Russia", "Rwanda", "Serbia", "Singapore", "Slovakia", "Slovenia", "South Africa", "Spain", "Sri Lanka", "Sweden", "Switzerland", "Tajikistan", "Tanzania", "Thailand", "Ukraine", "United Kingdom", "Uruguay", "Uzbekistan", "Vietnam", "Zambia", "Zimbabwe"], "y": [45.63, 72.77, 63.3, 75.74, 92.62, 89.51, 71.71, 64.83, 72.09, 79.57, 83.83, 68.52, 74.28, 52.62, 77.48, 44.16, 55.42, 90.99, 75.86, 63.35, 55.63, 68.83, 75.94, 73.97, 79.98, 87.61, 88.71, 54.14, 78.13, 76.28, 87.04, 80.26, 66.55, 88.61, 81.23, 79.22, 94.11, 76.88, 49.46, 89.35, 75.62, 56.82, 96.26, 67.17, 57.25, 92.62, 77.28, 64.61, 74.36, 82.54, 74.71, 73.97, 82.68, 81.39, 54.4, 69.44, 56.44, 59.98, 89.87, 92.64, 90.26, 51.43, 66.05, 64.15, 55.37, 86.11, 87.89, 78.29, 53.38, 56.52, 73.47, 96.88, 86.94, 87.66, 50.41, 83.34, 72.32, 88.75, 89.77, 66.61, 66.06, 57.0, 57.68, 82.77, 64.28, 67.7, 75.97, 60.61, 42.79]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola

# %% [markdown]
# ### Number of countries and it behavior

# %%
fig, ax = plt.subplots(figsize=(4,6), subplot_kw=dict(aspect="equal"))

r = ["39 Decresed in PSI ","54 Incresed in PSI "]

data = [39, 54]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40,colors=cols)

bbox_props = dict(boxstyle="square,pad=0.4", fc="w", ec="k", lw=3)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(r[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title(" Number of Countries with increase PSI vs decrese PSI")

plt.show()

# %% [markdown]
# ### Top increseing in the PSI

# %%
sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

bot_15_2017 = ps[ps['Personl_change_rate']>0].sort_values(by='Personl_change_rate',ascending=False).head(10)
bot_15_2017.plot('Country', 'Personl_change_rate', kind='bar', figsize=(14,10), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('PSI Change_rate')
plt.title('Highest Incresed In The PSI Change Rate')
# Out:
# Text(0.5, 1.0, 'Highest Incresed In The PSI Change Rate')

# %% [markdown]
# ### Top Decresing in the PSI

# %%
sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

bot_15_2017 = ps[ps['Personl_change_rate']<0].sort_values(by='Personl_change_rate').head(10)
bot_15_2017.plot('Country', 'Personl_change_rate', kind='bar', figsize=(14,10), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('PSI Change_rate')
plt.title('Highest Decrese In The PSI Change Rate')
# Out:
# Text(0.5, 1.0, 'Highest Decrese In The PSI Change Rate')

# %% [markdown]
# ### Now lets take the 54 countries that now we know they passed both the first and second critic overviews to the last part.

# %%
#third_t = incresed_ps.to_csv('third_t__.csv')

# %% [markdown]
# ------------

# %% [markdown]
# ----------

# %% [markdown]
# # Fourth part- Debt-to-GDP
#
#
# The debt-to-GDP percentage is the metric comparing a country's public debt to its gross domestic product (GDP). By comparing what a country owes with what it produces, the debt-to-GDP ratio reliably indicates that particular country’s ability to pay back its debts, however,<font color="red"> there was one Country with no dept to gpd data </font>
#
# - what i am going to check ?
#  - First, does all countries that now have passed the pm.2.5 and personal saftey and had a incresed hdi will contrubuited positivly to the debt-to-GDP percentage ?
#     - second, how many of the top 20 countries incrrese in the dept ?
#
#  - finaly, take healthier countries that had less than 77% of ebt-to-GDP percentage to be the finale winners in this project !
#
#    lets see !

# %%
dept = pd.read_csv('dept_to_gpd.csv')

# %%
dept.shape
# Out:
# (53, 8)

# %%
dept.columns
# Out:
# Index(['Country', 'dt_2012', 'dt_2013', 'dt_2014', 'dt_2015', 'dt_2016',
#        'dt_2017', 'dt_2018'],
#       dtype='object')

# %%
#define the top 20 in the HDI ranking 
top_countries =['Norway','Luxembourg','Switzerland','Ireland','Germany','Australia','Iceland','Sweden','Singapore','Netherlands','Denmark','Finland','Canada','New Zealand','United Kingdom','United States',
'Belgium','Liechtenstein','Japan','Austria']

# %%
top =[]
for i in dept.Country:
    if i in top_countries:
        top.append(1)
    else:
        top.append(0)

# %%
dept['is_top_20']= top

# %%
dept['change_rate_dt']= (dept['dt_2017']- dept['dt_2012'])/dept['dt_2012']*100

# %%
decrese_dept = dept[(dept['change_rate_dt'] <0)] # countries with decresed dept
decrese_dept.shape
# Out:
# (16, 10)

# %%
increse_dept = dept[(dept['change_rate_dt'] >0)] # countries with decresed dept
increse_dept.shape
# Out:
# (37, 10)

# %%
Theory_3 = pd.DataFrame()

# %%
Theory_3['Incresed%'] = [increse_dept.index.value_counts().sum()/dept.index.value_counts().sum() *100]
Theory_3['Decresed%'] = [decrese_dept.index.value_counts().sum()/dept.index.value_counts().sum() *100]

# %%
Theory_3
# Out:
#    Incresed%  Decresed%
# 0  69.811321  30.188679

# %% [markdown]
# 70% of these countries actully incresed in thier dept......

# %% [markdown]
# _________

# %%
#fined the healthieist countries

# %%
#Remove countries higher than 77% dept to gpd

# %%
healthy_countries = decrese_dept[decrese_dept['dt_2018'] <= 77]

# %%
healthy_countries.shape
# Out:
# (15, 10)

# %%
healthy_countries.shape
# Out:
# (15, 10)

# %%
healthy_countries.sort_values(by='change_rate_dt')
# Out:
#            Country  dt_2012  dt_2013  dt_2014  dt_2015  dt_2016  dt_2017  \
# 18         Iceland   89.369   81.789   79.727   65.955   51.697   39.958
# 21         Ireland  119.925  119.817  104.265   76.931   73.556   68.555
# 10  Czech Republic   44.470   44.909   42.169   39.955   36.806   34.669
# 11         Denmark   44.894   44.046   44.270   39.926   37.868   35.294
# 33     Netherlands   65.511   67.005   67.100   63.970   61.299   56.450
# 34     New Zealand   35.724   34.606   34.234   34.300   33.455   31.696
# 13         Estonia    9.733   10.161   10.667   10.001    9.417    8.980
# 38          Poland   53.716   55.692   50.253   51.122   54.162   50.622
# 14            Fiji   51.621   49.664   48.214   46.205   47.465   48.864
# 49     Switzerland   43.668   42.914   42.971   43.007   41.843   41.815
# 3          Austria   81.611   81.011   83.799   84.346   83.556   78.550
# 40         Romania   37.738   39.026   40.494   39.352   38.762   36.778
# 44        Slovakia   52.165   54.739   53.547   52.341   51.819   50.864
# 30        Malaysia   54.552   56.447   56.160   57.877   56.183   54.123
# 28       Lithuania   39.774   38.759   40.541   42.589   40.107   39.734
#
#     dt_2018  is_top_20  change_rate_dt
# 18   37.022          1      -55.288747
# 21   66.577          1      -42.835105
# 10   33.166          0      -22.039577
# 11   34.739          1      -21.383704
# 33   53.099          1      -13.831265
# 34   30.357          1      -11.275333
# 13    8.802          0       -7.736566
# 38   49.988          0       -5.759923
# 14   49.761          0       -5.340850
# 49   40.155          1       -4.243382
# 3    74.237          1       -3.750720
# 40   37.185          0       -2.543855
# 44   49.236          0       -2.494009
# 30   55.101          0       -0.786406
# 28   36.956          0       -0.100568

# %% [markdown]
# # These are the countries which succesed in :
#    ####  *Maintain increasing their HDI.
#    #### * Maintain decresing their pm.2.5 rates.
#    #### * Maintain increasing their personal saftey index.
#    #### * Maintain  decresing their dept and was less than 77%.
#
#  ### which only represent only 9.37% of the countries with incresed HDI

# %% [markdown]
# # Visualztion of the fourth part :
#     -

# %% [markdown]
# ### General overview of the changes

# %%
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure()
fig.add_trace(go.Scatter(
                x=dept['Country'],
                y=dept['dt_2012'],
                name="Dept to GPD % in 2012",
                line_color='blue',
                opacity=0.8))

fig.add_trace(go.Scatter(
                x=dept['Country'],
                y=dept['dt_2017'],
                name="Dept to GPD % in 2017",
                line_color='green',
                opacity=0.8))
# Use date string to set xaxis range
title_text="Changes Between 2012-2017"
fig.show()
# Out:
# <div>
#
#
#             <div id="410bad77-a006-49b1-9011-7783fb36040b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("410bad77-a006-49b1-9011-7783fb36040b")) {
#                     Plotly.newPlot(
#                         '410bad77-a006-49b1-9011-7783fb36040b',
#                         [{"line": {"color": "blue"}, "name": "Dept to GPD % in 2012", "opacity": 0.8, "type": "scatter", "x": ["Afghanistan", "Argentina", "Australia", "Austria", "Belarus", "Bhutan", "Bolivia", "Canada", "China", "Colombia", "Czech Republic", "Denmark", "Dominican Republic", "Estonia", "Fiji", "Finland", "France", "Greece", "Iceland", "Indonesia", "Iraq", "Ireland", "Italy", "Japan", "Kazakhstan", "Kenya", "Korea", "Kyrgyzstan", "Lithuania", "Luxembourg", "Malaysia", "Mauritius", "Mexico", "Netherlands", "New Zealand", "Norway", "Paraguay", "Peru", "Poland", "Portugal", "Romania", "Russia", "Rwanda", "Singapore", "Slovakia", "Slovenia", "South Africa", "Spain", "Sri Lanka", "Switzerland", "Tanzania", "Uzbekistan", "Zambia"], "y": [6.769, 38.949, 27.773000000000003, 81.611, 36.946, 76.264, 35.394, 84.84, 34.269, 33.998000000000005, 44.47, 44.894, 29.999000000000002, 9.732999999999999, 51.621, 53.91, 90.602, 159.586, 89.369, 22.96, 34.782, 119.925, 123.36, 229.00799999999998, 12.125, 43.88, 32.201, 48.975, 39.774, 21.72, 54.552, 56.6, 42.65, 65.51100000000001, 35.724000000000004, 30.16, 11.937000000000001, 21.166, 53.716, 126.22200000000001, 37.738, 11.908, 19.97, 105.08200000000001, 52.165, 53.786, 41.0, 85.73700000000001, 69.609, 43.668, 29.151, 11.189, 25.425]}, {"line": {"color": "green"}, "name": "Dept to GPD % in 2017", "opacity": 0.8, "type": "scatter", "x": ["Afghanistan", "Argentina", "Australia", "Austria", "Belarus", "Bhutan", "Bolivia", "Canada", "China", "Colombia", "Czech Republic", "Denmark", "Dominican Republic", "Estonia", "Fiji", "Finland", "France", "Greece", "Iceland", "Indonesia", "Iraq", "Ireland", "Italy", "Japan", "Kazakhstan", "Kenya", "Korea", "Kyrgyzstan", "Lithuania", "Luxembourg", "Malaysia", "Mauritius", "Mexico", "Netherlands", "New Zealand", "Norway", "Paraguay", "Peru", "Poland", "Portugal", "Romania", "Russia", "Rwanda", "Singapore", "Slovakia", "Slovenia", "South Africa", "Spain", "Sri Lanka", "Switzerland", "Tanzania", "Uzbekistan", "Zambia"], "y": [7.004, 57.576, 40.806999999999995, 78.55, 53.437, 106.31299999999999, 48.963, 89.727, 46.96, 49.354, 34.669000000000004, 35.294000000000004, 37.202, 8.98, 48.864, 61.332, 96.801, 181.77900000000002, 39.958, 28.768, 59.726000000000006, 68.555, 131.808, 237.64700000000002, 20.791999999999998, 54.217, 39.529, 55.952, 39.734, 22.95, 54.123000000000005, 63.977, 54.332, 56.45, 31.695999999999998, 36.461999999999996, 19.452, 25.429000000000002, 50.622, 125.682, 36.778, 15.53, 40.455999999999996, 111.105, 50.864, 73.617, 53.04, 98.36399999999999, 79.102, 41.815, 36.972, 24.259, 63.102]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ### Number of countries and thier behaivour

# %%
fig, ax = plt.subplots(figsize=(4,6), subplot_kw=dict(aspect="equal"))

r = ["16 Countries Decresed ","30 Countries Incresed"]

data = [16, 30]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40,colors=cols)

bbox_props = dict(boxstyle="square,pad=0.4", fc="w", ec="k", lw=3)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(r[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title(" Number of Countries With Increase vs Decrease dept to gpd %")

plt.show()

# %%
import plotly.graph_objects as go

labels = ['Is from top 20', 'Rest of countries']
values = [7, 30]

# pull is given as a fraction of the pie radius
fig = go.Figure(data=[go.Pie(labels=labels, values=values, pull=[0.2, 0.2, 0.2, 0.2],marker_colors=cols)] )
fig.update_layout(title_text=' of which are within the Top 20 Countries')
fig.show()
# Out:
# <div>
#
#
#             <div id="689dc877-3a61-4d78-8941-4d6f0f158e31" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("689dc877-3a61-4d78-8941-4d6f0f158e31")) {
#                     Plotly.newPlot(
#                         '689dc877-3a61-4d78-8941-4d6f0f158e31',
#                         [{"labels": ["Is from top 20", "Rest of countries"], "marker": {"colors": ["#B2E0F0", "#174147", "#BFD1D7"]}, "pull": [0.2, 0.2, 0.2, 0.2], "type": "pie", "values": [7, 30]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ### Highest Decrese in thier depts

# %%
sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

bot_15_2017 = dept[(dept['change_rate_dt'] <0)].sort_values(by='change_rate_dt').head(10)
bot_15_2017.plot('Country', 'change_rate_dt', kind='bar', figsize=(14,10), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('Dept to gpd % Change_rate')
plt.title('Highest Incresed In The Dept to gpd % Change Rate')
# Out:
# Text(0.5, 1.0, 'Highest Incresed In The Dept to gpd % Change Rate')

# %%
sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

bot_15_2017 = dept[(dept['change_rate_dt'] >0)].sort_values(by='change_rate_dt').head(10)
bot_15_2017.plot('Country', 'change_rate_dt', kind='bar', figsize=(14,10), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('Dept to gpd % Change_rate')
plt.title('Highest Incresed In The Dept to gpd % Change Rate')
# Out:
# Text(0.5, 1.0, 'Highest Incresed In The Dept to gpd % Change Rate')

# %%
# getting the healthieisy countries with less than 77% dept to gpd % by the 2018 year 

sns.set_palette(sns.dark_palette("green",15, reverse=False))
sns.set_style('whitegrid')

bot_15_2017 = decrese_dept[decrese_dept['dt_2018'] <= 77].sort_values(by='dt_2018')
bot_15_2017.plot('Country', 'dt_2018', kind='bar', figsize=(14,10), rot=45, colors = co)

plt.xlabel('COUNTRIES')
plt.ylabel('Dept to gpd %')
plt.title('healthier cointires')
# Out:
# Text(0.5, 1.0, 'healthier cointires')

# %%
top_15= pd.read_csv('top_15.csv')

# %%
top_15.set_index('Country', inplace=True)

# %%
#top_15.plot(kind='bar');
ax = top_15.plot(kind='bar', figsize=(15,14),colors = co);

# Set the title.
ax.set_title('Healthiest Countries ', fontsize=21, y=1.01);

# Move the legend.
ax.legend(loc=2);

# x-axis labels

# y-axis labels
ax.set_xlabel('Countries', fontsize=16);

# %%
import plotly.graph_objects as go

labels = ['Healthier Countries', 'Rest of countries']
values = [15,160]

# pull is given as a fraction of the pie radius
fig = go.Figure(data=[go.Pie(labels=labels, values=values, pull=[0.2, 0.2, 0.2, 0.2],marker_colors=cols)] )
fig.update_layout(title_text=' Passed Countries')
fig.show()
# Out:
# <div>
#
#
#             <div id="db6dba53-e861-4d5e-b79d-5749289a5301" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db6dba53-e861-4d5e-b79d-5749289a5301")) {
#                     Plotly.newPlot(
#                         'db6dba53-e861-4d5e-b79d-5749289a5301',
#                         [{"labels": ["Healthier Countries", "Rest of countries"], "marker": {"colors": ["#B2E0F0", "#174147", "#BFD1D7"]}, "pull": [0.2, 0.2, 0.2, 0.2], "type": "pie", "values": [15, 160]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
